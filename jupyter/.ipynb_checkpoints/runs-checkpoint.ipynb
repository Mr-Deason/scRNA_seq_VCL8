# %%
import os
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd

df = pd.read_csv("runs.csv")
df = df.drop('all', axis=1)
ka = df['kallisto']
df = df.drop('kallisto', axis=1)


df.insert(0, 'kallisto', ka)

var = df.groupby(['size', 'source']).sum().stack()
var.unstack().plot(kind='bar', stacked=True)
plt.show()

# %%
sz = df.ix[:, 'size']
sz = list(sz)
sz = np.unique(sz)
print sz
for size in sz:
    data = df[df['size'] == size]
    data = data.drop('size', axis=1)
    print data
    var = data.groupby('source').sum().stack()
    var.unstack().plot(kind='bar', stacked=True, title=size)
plt.show()
# Out:
# ['100k' '10k' '10m' '1m' '5m']
#    kallisto source  get  error  compute
# 1        47    cpp    2     29       25
# 6        48     py   24     26      157
#    kallisto source  get  error  compute
# 0        42    cpp    0      2        4
# 5        42     py   23      5      160
#    kallisto source  get  error  compute
# 4        75    cpp  183   3020       90
#    kallisto source  get  error  compute
# 2        70    cpp   18    292      164
# 7        78     py   51    246      200
#    kallisto source  get  error  compute
# 3        80    cpp   90   1259      134
# 8       228     py  171   3566      338
